# %% [markdown]
# # My first notebook

# %% [markdown]
# # Chapter 1

# %% [markdown]
# ### Variables and calculating

# %%
10+2
# Out:
# 12

# %%
10//5
# Out:
# 2

# %%
my_name="Yevhen"
my_name
# Out:
# 'Yevhen'

# %%
my_str_dict={
    'name': 'Yevhen',
    'status': 'passed',
    'position': "student",
}

new_dict = {k: v.upper() for k,v in my_str_dict.items()}

print(new_dict)
# Out:
# {'name': 'YEVHEN', 'status': 'PASSED', 'position': 'STUDENT'}

# %% [markdown]
# ### Functions

# %%
def say_hello(val):
    return print(f"Hello {val}!" )

say_hello(my_name)
# Out:
# Hello Yevhen!

# %% [markdown]
# ### Lybraries

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.cos(range(20)))
